# %% [markdown]
# # 簡單文字雲示範

# %%
import nltk
from wordcloud import WordCloud

text = open('data/example.txt', 'r', encoding='utf-8').read() #匯資料
text = ' '.join(nltk.word_tokenize(text)) #斷詞依據
cloud = WordCloud().generate(text) #形成文字雲
cloud.to_file('img/output.png')

# %% [markdown]
# ![title](img/output.png)

# %% [markdown]
# ## 粉專文字雲比較
# 先匯入套件並整理資料

# %%
import pandas as pd
import jieba

df = pd.read_csv("data/10802_2020_party.csv") #匯資料
df["Post_Date"] = df["Date"].str.split(" ").str.get(0).str.title() #加Post_Date欄位

df_blue_New = df[df['Page_Name']=='中國國民黨 KMT'][['Message']] 
df_green_New = df[df['Page_Name']=='民主進步黨'][['Message']] 

df_blue_New = df_blue_New.dropna()
df_green_New = df_green_New.dropna()
# Out:
#                                                 Message
# 31    今日挺韓「南方崛起高雄光榮周年慶大遊行」 下午1點11分準時出發\n全程我們都是秉持著理性且...
# 100   【元旦升旗，不見不散】\n\n你有多久沒有唱國歌、升國旗了？迎接明年元旦，我們一起升旗吧！國...
# 104   【支持總統候選人 2號韓國瑜】\n\n🇹🇼２隻穿雲箭，２號國政配🇹🇼\n🇹🇼韓國瑜當選，立法...
# 156   【初選過關，團結投藍】\n\n經過公平公正公開的民調作業，\n韓國瑜同志從總統初選中出線，\...
# 206   【力挺韓國瑜，上架中華民國派】\n\n相信昨天的「南方崛起高雄光榮週年慶」大遊行，仍然讓我們...
# ...                                                 ...
# 3772                        #蔡英文總統執政3週年回顧\n【「碳氣」的台灣】記者會
# 3773  【15縣市公平對待！阿義哥有話要對中央政府說】\n大家好，吳主席今天下午在粉絲專頁跟大家分享...
# 3774                    主席在「周玉蔻嗆新聞」台北之音FM107.7 和大家在空中相見
# 3783  【年節時歲暖心報：清明 榖雨】\n清明穀雨、草木萌芽，逐漸暖和的天氣裡，偶爾會有來自東南方的...
# 3805  【空汙越來越嚴重，難道要用愛發電嗎？】\n\n「以核養綠」與「反燃煤電廠」公投雙雙過關，蔡英...
#
# [482 rows x 1 columns]

# %% [markdown]
# 定義待會要用到的停用字字典還有自定義字典

# %%
def stopwordslist(filepath):  
    stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]  
    return stopwords  

def seg_sentence(sentence):  
    jieba.load_userdict("dict/user.txt")
    sentence_seged = jieba.cut(sentence)  
    stopwords = stopwordslist('dict/stop_words.txt') 
    outstr = ''  
    for word in sentence_seged:  
        if word not in stopwords:  
            if word != '\t':  
                outstr += word  
                outstr += ' ' 
    return outstr  

def not_load_dict(sentence):
    sentence_seged = jieba.cut(sentence)  
    outstr = ''  
    for word in sentence_seged:  
        outstr += word  
        outstr += ' ' 
    return outstr  

def get_list(df):
    index_ = list(df.index)
    word_list =''
    for i in index_:
        word_list += df['Message'][i]
    
    return word_list

# %% [markdown]
# ### 國民黨的文字雲

# %%
#呼叫上面的函式進行斷詞
word_list = get_list(df_blue_New)
test = seg_sentence(word_list)
word_list
# Out:
# '今日挺韓「南方崛起高雄光榮周年慶大遊行」 下午1點11分準時出發\n全程我們都是秉持著理性且支持韓國瑜候選人的態度\n在高雄遊行，訴諸我們人民的真實聲音\n不管是支持又或是不支持，我們都是在訴諸民主\n我們都是中華民國的國民！\n\n今日我們為高雄注入了全新的力量，人潮、錢潮！\n\n#明年1月11日\n#唯一支持2號總統候選人韓國瑜\n#政黨票9號中國國民黨\n#中國國民黨立委候選人【元旦升旗，不見不散】\n\n你有多久沒有唱國歌、升國旗了？迎接明年元旦，我們一起升旗吧！國民黨主席吳敦義、國民黨副總統候選人張善政與前總統馬英九將與您一起迎接光明未來，我們不見不散！\n\n．時間：民國109年1月1日上午7點\n．地點：國民黨中央黨部（台北市八德路二段232號戶外）【支持總統候選人 2號韓國瑜】\n\n🇹🇼２隻穿雲箭，２號國政配🇹🇼\n🇹🇼韓國瑜當選，立法院過半🇹🇼\n🇹🇼２０２０年，下架蔡英文🇹🇼\n\n#總統支持2號國政配\n#立委支持國民黨提名候選人\n#政黨票支持中國國民黨【初選過關，團結投藍】\n\n經過公平公正公開的民調作業，\n韓國瑜同志從總統初選中出線，\n今天正式通過了中常會的核備，\n將會提交7月28日全代會通過。\n\n面對台灣民主被蔡英文步步侵蝕，\n面對中華民國被民進黨借殼上市，\n我們只有團結一心，重返執政，\n才能撥亂反正、藍天再現！【力挺韓國瑜，上架中華民國派】\n\n相信昨天的「南方崛起高雄光榮週年慶」大遊行，仍然讓我們印象深刻！飄揚的國旗與擠爆的民眾，已經證明守護中華民國、反對獨裁退步，是大家所重視的價值。讓光榮從高雄出發！\n\n超過35萬人熱情相挺，展現出庶民的真實心聲。我們不必用「騙人布」遮掩，也無須用灌水的數字膨風，我們並不孤單，假網軍抵不過真民意！\n\n#總統支持2號韓國瑜\n#政黨支持9號國民黨\n#地方支持國民黨提名候選人【蔣公精神，永在人間：蔣公逝世44周年】\n\n今天，不只是清明節。民國64年4月5日晚間11時50分，蔣中正因突發性心臟病逝世。也是中國國民黨總裁逝世的日子，享年89歲。\n\n在那風雨飄搖的歲月裡，台灣百廢待舉，蔣中正與其領導的中華民國政府胼手胝足，從三七五減租、公地放領再到九年國教、經濟發展，讓台灣成為一個更為進步的社會。因此，他的逝世也帶給國民極大的衝擊，前往國父紀念館悼念的人潮絡繹於途。\n\n我們固然不需要過度神化蔣公，但也不應該全盤否定蔣中正的功績。 吳敦義 Wu, Den-Yih 主席便說，蔣公在台灣推動許多重大建設，使得台灣復興基地民生樂利、民族獲得尊榮、民生也得落實，讓三民主義在復興基地扎根，這些功績值得大家永遠懷念！#LIVE 中國國民黨元旦活動人民有言論自由，受害者站出來！#LIVE 「1/9 凱道勝利晚會宣傳」記者會，由總統候選人韓國瑜、韓國瑜競選辦公室總發言人王淺秋、發言人鄭照新出席，台北市黨部主委黃呂錦茹、新北市黨部主委李乾龍陪同出席。【國父誕辰154週年】\n\n知道這位帥氣的美男子是誰嗎❓\n他就是我們的國父孫中山先生😍\n\n距今110年前，國父辛苦奔走革命，\n這是他抵達巴黎籌款時的留影。\n作為國父思想的繼承者，\n我們不會忘記國父的理想與志業！\n\n「民生凋敝\u3000國步艱難\u3000禍患猶未已\n\u3000莫散了團體\u3000休灰了志氣\u3000大家要互相勉勵\n\u3000國父遺言\u3000不要忘記\u3000革命尚未成功\u3000同志仍須努力」\n\n（圖為一九零九年五月，國父赴歐洲籌款，抵達巴黎時留影。黨史館提供）【中華民國，生日快樂！】\n\n108年前的今天，是革命黨人在武昌成功起義，催生中華民國的日子。從那天起，我們推翻了帝制，朝民主自由的理想更邁進了一步。\n\n中華民國締造的過程，並非一帆風順，甚至曾遭遇慘痛的失敗。然而，在大時代的風風雨雨下，中華民國依然挺立。這是民國46年的總統府前國慶典禮（黨史館提供），即便國家內憂外患紛至沓來，依然展現出熱烈慶祝國慶的熱情！\n\n今天，中華民國仍持續在台澎金馬昂然矗立，我們將繼續把中華民國高高舉起，讓青天白日滿地紅的國旗堂而皇之的飄揚在每個縣市！【集中選票，支持韓國瑜當選！】\n\n大選的決戰時刻終於到了！這絕不是一場三分天下的選舉，而是國民黨與民進黨就中華民國國家發展總路線之爭。陳水扁在1994年跟2000年兩度漁翁得利，選民豈可再上當？把選票支持第三對象，其實就是幫助蔡英文當選！\n\n為了捍衛中華民國，守護台灣，唯有在1月11日踴躍投票，集中選票，團結支持韓國瑜，下架民進黨，台灣才有前途！讓藍天再現，撥亂反正，才能讓中華民國走回正軌！\n\n#台灣安全 #人民有錢\n#總統票集中支持2號韓國瑜\n#政黨票集中支持9號國民黨\n#立委支持國民黨提名候選人【政黨票請投９號中國國民黨】\n\n投９號救台灣、救中華民國！\n投９號救經濟、救民主自由！\n\n下架無能、傲慢、濫權、酬庸的民進黨，\n上架廉能、公義、穩定、全力拚經濟的國民黨！\n\n#總統支持２號韓國瑜\n#政黨票投９號國民黨\n#區域支持國民黨提名候選人【LIVE】愛國旗，愛國家，108年民辦國慶大典#LIVE 韓國瑜競選辦公室召開「新年新希望：事實查核終結蔡英文十大騙局！」以及「沉痛！反滲透法帶台灣走回戒嚴！」雙主題記者會，總發言人王淺秋、發言人鄭照新、發言人葉元之、發言人何庭歡出席。【對不起，民進黨】\n\n對不起。\n沒有投民進黨候選人，對不起。\n讓妳坐雲豹甲車勘災，對不起。\n反對妳要的肺咳家園，對不起。\n\n對不起。\n抗議勞基法一例一休，對不起。\n無法把低薪當作功德，對不起。\n反對走私是擅自移動，對不起。\n\n對不起。\n妳三年斷交七個邦交國，\n妳台商回流七千億變零，\n網軍害死人妳查無真相，\n讓妳執政，我很抱歉。\n\n對不起，民進黨。\n人民已覺醒，不會再投你。\n\n#對不起民進黨\n#對不起蔡英文\n#在此明文規定鄭重道歉【直播】消滅網軍東廠，還台灣公道，還人民公道【1月11日，用選票下架蔡英文】\n\n●無能：空汙危害人民，政府束手無策\n●傲慢：雲豹甲車勘災，粗暴飆罵記者\n●濫權：硬推一例一休，關公投進鐵籠\n●酬庸：無專業領高薪，酬庸民進黨人\n\n明年讓我們用選票下架無能、傲慢、濫權、酬庸的民進黨政府！\n\n#上架中華民國派\n#政黨票支持9號國民黨\n#總統票支持2號韓國瑜\n#立委票支持國民黨提名人選#LIVE「誰在扼殺言論自由?」記者會，參加人員: 打鬼軍團總團長 周錫瑋、台北市議員(文傳會副主委兼發言人)王鴻薇、捉鬼大隊總團長邱錦添、魏平政律師，以及10名被查水表民眾。#LIVE「集中選票 力挺韓國瑜當選」 記者會，由韓國瑜競選總部總幹事曾永權主持，執行副總幹事周錫瑋、曾銘宗、姚江臨出席。【LIVE】追！楊蕙如金主：爆中央南北都中標#LIVE 盼亡者安息 傷者早日康復【LIVE】民進黨踐踏司法大事記【凱道大會師！支持韓國瑜前進總統府】\n\n只等那信號一亮，只等那信號一響。我們就展開閃電攻擊，打一個轟轟烈烈的勝仗！\n\n1月9日下午5點，將在凱達格蘭大道正式開始，大家一起站出來，表達對中華民國的信念與熱愛，展現支持韓國瑜前進總統府的聲浪！\n\n#百萬庶民站出來\n#台灣安全人民有錢\n#政黨投９總統投２#LIVE 韓國瑜競選辦公室召開「全民搜尋！楊蕙如現蹤！」記者會，副總幹事周錫瑋、總發言人王淺秋、發言人鄭照新、發言人何庭歡出席。【守護兩岸和平，全力以赴勝選】\n\n吳敦義 Wu, Den-Yih主席一聲令下，\n「好，拚了！」\n\n我們拚了，\n為支持韓國瑜高票當選總統，\n為支持本黨提名立委至少當選60席，\n我們一定要努力做，\n這是我們絕對不改的立場！\n\n我們拚了，\n為了我們國家的未來，\n為了兩岸關係的發展，\n堅持一中各表的九二共識，\n「俱往矣，數當前明路，和平最好！」\n\n為了國家，我們拚了！\n\n#反攻大陸已成歷史\n#解放台灣又嫌霸道\n#當前明路和平最好【LIVE】\n反民進黨鎖國，青年要國際化！「1/11為自己而投」青年回家投票記者會並發布影片，由國民黨青年部主任蕭敬嚴、副主任詹為元共同主持，並邀請多位青年朋友出席。【LIVE】「重啟特偵組！十大疑案追追追」記者會，出席者：台北市議員王鴻薇、新北市議員唐慧琳、不分區立委候選人吳怡玎。【LIVE】慶富案超貸追追追記者會【LIVE】再追！民進黨的暗黑網軍\n由「要正義」連線張顯耀、蔡正元、邱毅，進一步說清楚講明白民進黨的暗黑網軍。【LIVE】韓國瑜競選辦公室「政見會蔡總統膨風的經濟數字釋疑」與「愛心義賣會準備開跑啦！」記者會#LIVE「集中選票 別讓蔡英文偷笑」記者會，由韓國瑜全國競選總部總幹事曾永權、副總幹事周錫瑋、曾銘宗與姚江臨共同主持。【LIVE】民進黨呷飽未？十大酬庸肥貓現形【LIVE】民進黨的暗黑網軍：蔡正元、張顯耀、邱毅與會【直播】提告媒體不實報導記者會【LIVE】韓競辦記者會回應辯論會重點：蔡英文假裝聽不到的韓國瑜競選政見【LIVE】韓國瑜競選辦公室「第三次政見發表會回應」記者會，出席者：總發言人王淺秋、發言人鄭照新、國政顧問團經濟組召集人 林祖嘉。【元旦快樂！嶄新的未來即將上架！】\n\n今天是2020年的第一天，迎向嶄新的未來，祝大家元旦快樂！\n1月11日，記得要投對人、選對黨，讓中華民國派上架，台灣的民主自由與中華民國的國家發展才會有希望！\n\n#總統票投2號國政配\n#政黨票投9號國民黨\n#區域立委投國民黨提名候選人【綠色恐怖：再見 ...

# %%
#畫出文字雲
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.pyplot as plt

font = 'D:/coding_resource/fourth_grade/politic_python/code/1_temp/code_mine/406_code/dict/simfang.ttf'
sns.set(rc={'figure.figsize':(10,6)})
my_wordcloud = WordCloud(background_color="white", scale=4, font_path=font,
                         max_words = 100,max_font_size = 60,random_state=20).generate(test)
my_wordcloud.to_file('img/blue_cloud.jpg')

# %% [markdown]
# ![title](img/blue_cloud.jpg)

# %% [markdown]
# ### 民進黨的文字雲

# %%
word_list = get_list(df_green_New)
test = seg_sentence(word_list)

sns.set(rc={'figure.figsize':(10,6)})
my_wordcloud = WordCloud(background_color="white", scale=4, font_path=font,
                         max_words = 100,max_font_size = 60,random_state=20).generate(test)
my_wordcloud.to_file('img/green_cloud.jpg')
# plt.imshow(my_wordcloud)
# plt.axis("off")
# plt.show()

# %% [markdown]
# ![title](img/green_cloud.jpg)

# %% [markdown]
# ## 共線圖

# %%
import pandas as pd
import jieba
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_csv("data/10802_2020_party.csv") #匯資料
df["Post_Date"] = df["Date"].str.split(" ").str.get(0).str.title() #加Post_Date欄位

df_blue_New = df[df['Page_Name']=='中國國民黨 KMT'][['Message','Post_Date']] #只要國民黨的文章和時間
df_terms = df_blue_New

# %%
#設定停用字
stopWords = []
with open('dict/stop_words.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        stopWords.append(data)
        
stoplst = [' ', '\xa0']
for words in stoplst:
    stopWords.append(words)

# %%
#設定自訂字典
with open('dict/user.txt', 'r', encoding='UTF-8') as file:
    for data in file.readlines():
        data = data.strip()
        jieba.add_word(data)

# %%
#開始斷詞並載入常用字與停用字字典
names = {}          
relationships = {}  
lineNames = []     

for i in range(len(df_terms['Message'])):
    try:
        poss = jieba.cut(df_terms['Message'][i], cut_all = False)
        lineNames.append([])
        for w in poss:
            if w not in stopWords:
                lineNames[-1].append(w)        
            if names.get(w) is None and w not in stopWords:
                names[w] = 0
                relationships[w] = {}
                names[w] += 1   
    except:
        pass

for line in lineNames:                  
    for name1 in line:                  
        for name2 in line:             
            if name1 == name2:
                continue
            if relationships[name1].get(name2) is None:     
                relationships[name1][name2]= 1
            else:
                relationships[name1][name2] = relationships[name1][name2]+ 1       
co_occur_by_records = [[name, v, w] for name, edges in relationships.items() for v, w in edges.items() if w > 25]

# %%
#形成co-occurance矩陣
np.random.shuffle(co_occur_by_records)
temp_matrix = pd.DataFrame()
for i in co_occur_by_records:
    temp_matrix.at[i[0], i[1]] = i[2]
co_occurrence_matrix_by_records = pd.DataFrame()
for i in temp_matrix:
    for j in temp_matrix:
        co_occurrence_matrix_by_records.at[i, j] = temp_matrix.at[i, j]
co_occurrence_matrix_by_records.head()

def sigmoid(x):
    return 1/(1 + np.exp(-x))
count_by_records = [i[2] for i in co_occur_by_records]
co_occur_by_records_sig = []
for i in co_occur_by_records:
    co_occur_by_records_sig.append([i[0], i[1], sigmoid((i[2] - np.mean(count_by_records))/np.std(count_by_records))])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_value(self, index, col, value, takeable)
#    2900             engine = self.index._engine
# -> 2901             engine.set_value(series._values, index, value)
#    2902             return self
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '溪'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e219e075ecf1> in <module>
#       3 temp_matrix = pd.DataFrame()
#       4 for i in co_occur_by_records:
# ----> 5     temp_matrix.at[i[0], i[1]] = i[2]
#       6 co_occurrence_matrix_by_records = pd.DataFrame()
#       7 for i in temp_matrix:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#    2213         key = list(self._convert_key(key, is_setter=True))
#    2214         key.append(value)
# -> 2215         self.obj._set_value(*key, takeable=self._takeable)
#    2216
#    2217
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_value(self, index, col, value, takeable)
#    2907                 self.iloc[index, col] = value
#    2908             else:
# -> 2909                 self.loc[index, col] = value
#    2910             self._item_cache.pop(col, None)
#    2911
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     389                     index = self.obj._get_axis(i)
#     390                     labels = index.insert(len(index), key)
# --> 391                     self.obj._data = self.obj.reindex(labels, axis=i)._data
#     392                     self.obj._maybe_update_cacher(clear=True)
#     393                     self.obj._is_copy = None
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3974         kwargs.pop("axis", None)
#    3975         kwargs.pop("labels", None)
# -> 3976         return super().reindex(**kwargs)
#    3977
#    3978     def drop(
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3862         if index is not None:
#    3863             frame = frame._reindex_index(
# -> 3864                 index, method, copy, level, fill_value, limit, tolerance
#    3865             )
#    3866
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3884             copy=copy,
#    3885             fill_value=fill_value,
# -> 3886             allow_dups=False,
#    3887         )
#    3888
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1311
#    1312         new_values = algos.take_nd(
# -> 1313             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1314         )
#    1315
#
# KeyboardInterrupt:

# %%
#準備畫出關聯圖    
plt.figure(figsize=(15,15))

plt.rcParams['font.sans-serif']=['simsun']
plt.rcParams['font.family']='sans-serif'

g = nx.Graph()
g.add_weighted_edges_from(co_occur_by_records_sig)
pos=nx.spring_layout(g)
nx.draw_networkx_nodes(g, pos, alpha=0.8,node_size=[val*50 for (node, val) in g.degree()], node_color='#08c5b1')
nx.draw_networkx_edges(g, pos, node_color='b', alpha=0.2)
for p in pos:  # raise text positions
    pos[p][1] = pos[p][1] + 0.03
nx.draw_networkx_labels(g, pos, font_size = 15, font_family='sans-serif', alpha=0.8)
plt.title('以每篇貼文為一句', size = 14)
plt.suptitle('用詞共線圖',x = 0.51,y=0.92, fontsize=18)
#plt.savefig("用詞共線圖_以每筆通聯紀錄為一句.png", dpi=100)
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 127484 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56825 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 127481 missing from current font.
#   font.load_char(ord(s), flags=flags)
